# %%
import os, json
import pandas as pd

path = '../../datasets/aifdb/'
datasets = ['araucaria/']
paths_to_json = [path + ds for ds in datasets]
print(paths_to_json)
json_files = []
for path_to_json in paths_to_json:
    json_files = json_files + [path_to_json + pos_json for pos_json in os.listdir(path_to_json) if pos_json.endswith('.json')]
print(len(json_files))  # for me this prints ['foo.json']
# Out:
# ['../../datasets/aifdb/araucaria/']
# 662

# %%
import pandas as pd
from itertools import product

# CA = conflict
# RA = support
# TA = ?

result = []


for index, js in enumerate(json_files):
    args = []
    edges_list = []
    with open(js) as json_file:
        json_text = json.load(json_file)
        
        # Store nodes in a dataframe
        nodes = json_text['nodes']
        for node in nodes:
            args.append([node['nodeID'], node['type'], node['text']])
        nodes_df = pd.DataFrame(args, columns = ["nodeID", "type", "text"])

        # Store edges in a dataframe
        edges = json_text['edges']
        for edge in edges:
            edges_list.append([edge['edgeID'], edge['fromID'], edge['toID']])
        edges_df = pd.DataFrame(edges_list, columns = ["edgeID", "fromID", "toID"])
        
        arg_nodes = nodes_df.loc[nodes_df["type"].values == "I"]
        
        relationship_nodes = nodes_df.loc[(nodes_df["type"].values == "RA") | (nodes_df["type"].values == "CA")]
        
        for index, arg_row in arg_nodes.iterrows():
            node_child_edges = edges_df.loc[edges_df["fromID"] == arg_row["nodeID"]]
            for index, edge_row in node_child_edges.iterrows():
                if edge_row["toID"] in relationship_nodes["nodeID"].values:
                    # Locate with node
                    rel_node = relationship_nodes.loc[relationship_nodes["nodeID"] == edge_row["toID"]]
                    if len(rel_node["type"].values) > 0:
                        relationship = rel_node["type"].values[0]
                        # Get output node of relationship
                        out_edge = edges_df.loc[edges_df["fromID"].values == rel_node["nodeID"].values]
                        if len(out_edge["toID"].values) > 0:
                            out_node_ID = out_edge["toID"].values[0]
                            # get arguments from IDs
                            out_node_text = arg_nodes.loc[arg_nodes["nodeID"] == out_node_ID]["text"]
                            if len(out_node_text.values) > 0:
                                in_node_text = "\"" + arg_row["text"] + "\""
                                out_node_text = "\"" + out_node_text.values[0] + "\""
                                result.append([in_node_text, out_node_text, relationship])                            
                    
        
result_df = pd.DataFrame(result, columns = ["argument1", "argument2", "relationship"])
                
print(result_df)
# Out:
#                                               argument1  \
# 0     "empowering women in developing countries is f...
# 1     "Nelson pointed out that 80% of the consumptio...
# 2     "By not listening corporations risk losing tou...
# 3     "In a worldwide battle for talent not utilizin...
# 4     "If we do not utilize women we fail to utilize...
# ...                                                 ...
# 3350  "If a population grows more resources from the...
# 3351     "Perhaps they do not wish or need to be cured"
# 3352   "If we introduce medicines they will be useless"
# 3353  "Perhaps their medicines are more efficient th...
# 3354  "If they can cure with their own medicines the...
#
#                                               argument2 relationship
# 0      "We should listen to the women and empower them"           RA
# 1      "We should listen to the women and empower them"           RA
# 2      "We should listen to the women and empower them"           RA
# 3      "We should listen to the women and empower them"           RA
# 4      "We should listen to the women and empower them"           RA
# ...                                                 ...          ...
# 3350  "If in fact the population grows more resource...           RA
# 3351  "We should not introduce modern medicine in th...           RA
# 3352  "We should not introduce modern medicine in th...           RA
# 3353     "Perhaps they do not wish or need to be cured"           RA
# 3354     "Perhaps they do not wish or need to be cured"           RA
#
# [3355 rows x 3 columns]

# %%
attack_count = result_df[result_df['relationship'] == 'CA'].count().iloc[0]
print(attack_count)
# Out:
# 38

# %%
support_count = result_df[result_df['relationship'] == 'RA'].count().iloc[0]
print(support_count)
# Out:
# 3317

# %%
# Replace aifdb relationship codes with our own
node_attack_support_codes = ["RA", "CA"]

result_df.loc[result_df["relationship"] == "RA", "relationship"] = "s"
result_df.loc[result_df["relationship"] == "CA", "relationship"] = "a"

print(result_df)
# Out:
#                                               argument1  \
# 0     "empowering women in developing countries is f...
# 1     "Nelson pointed out that 80% of the consumptio...
# 2     "By not listening corporations risk losing tou...
# 3     "In a worldwide battle for talent not utilizin...
# 4     "If we do not utilize women we fail to utilize...
# ...                                                 ...
# 3350  "If a population grows more resources from the...
# 3351     "Perhaps they do not wish or need to be cured"
# 3352   "If we introduce medicines they will be useless"
# 3353  "Perhaps their medicines are more efficient th...
# 3354  "If they can cure with their own medicines the...
#
#                                               argument2 relationship
# 0      "We should listen to the women and empower them"            s
# 1      "We should listen to the women and empower them"            s
# 2      "We should listen to the women and empower them"            s
# 3      "We should listen to the women and empower them"            s
# 4      "We should listen to the women and empower them"            s
# ...                                                 ...          ...
# 3350  "If in fact the population grows more resource...            s
# 3351  "We should not introduce modern medicine in th...            s
# 3352  "We should not introduce modern medicine in th...            s
# 3353     "Perhaps they do not wish or need to be cured"            s
# 3354     "Perhaps they do not wish or need to be cured"            s
#
# [3355 rows x 3 columns]

# %%
# Create neutral relationships

n_pairs = []


for i in range(attack_count):
    sample = result_df.sample(n=2)
    text1 = sample.iloc[0]["argument1"]
    text2 = sample.iloc[1]["argument2"]
    
    pair = result_df.loc[(result_df["argument1"] == text1) & (result_df["argument2"] == text2)]
    
    
    if len(pair) == 0:
        n_pairs.append([text1, text2, "n"])

n_pairs_df = pd.DataFrame(n_pairs, columns = ["argument1", "argument2", "relationship"])
result_df = pd.concat([result_df, n_pairs_df], ignore_index=True)
print(result[0])
# Out:
# ['"empowering women in developing countries is four times as likely to improve health benefits for children."', '"We should listen to the women and empower them"', 'RA']

# %%
# Unabstract arguments

result_df.to_csv('model_training/training_data/araucaria_relationships_cleaned.csv')

# %%
df = pd.read_csv('../../datasets/IBM_Debater_(R)_arg_quality_rank_30k/arg_quality_rank_30k.csv')
df["relationship"] = ""
th_element = df.sort_values(by=['WA']).iloc[1000]
threshold = neutral_df.WA

#df.loc[df["stance_WA"] == 1].count()
#df.loc[df["stance_WA"] == -1].count()

# %%
df.head(10000)
# Out:
#                                                argument  \
# 0     "marriage" isn't keeping up with the times.  a...
# 1     .a multi-party system would be too confusing a...
# 2     \ero-tolerance policy in schools should not be...
# 3     `people reach their limit when it comes to the...
# 4     100% agree, should they do that, it would be a...
# ...                                                 ...
# 9995  it can be used to prevent a child being mental...
# 9996  it can be very beneficial for people with cert...
# 9997       it can be very educational and full of facts
# 9998  it can be viewed as undemocratic to force peop...
# 9999  it can become confusing when voting on a multi...
#
#                                                   topic    set        WA  \
# 0                            We should abandon marriage  train  0.846165
# 1                  We should adopt a multi-party system  train  0.891271
# 2     We should adopt a zero-tolerance policy in sch...    dev  0.721192
# 3         Assisted suicide should be a criminal offence  train  0.730395
# 4                         We should abolish safe spaces  train  0.236686
# ...                                                 ...    ...       ...
# 9995          We should ban cosmetic surgery for minors  train  0.727881
# 9996                        We should legalize cannabis   test  0.890397
# 9997                       We should abandon television  train  0.699708
# 9998              We should introduce compulsory voting  train  0.801551
# 9999               We should adopt a multi-party system  train  0.600007
#
#         MACE-P  stance_WA  stance_WA_conf relationship
# 0     0.297659          1        1.000000
# 1     0.726133         -1        1.000000
# 2     0.396953         -1        1.000000
# 3     0.225212         -1        1.000000
# 4     0.004104          1        0.805517
# ...        ...        ...             ...          ...
# 9995  0.368241         -1        1.000000
# 9996  0.713004          1        1.000000
# 9997  0.249363         -1        1.000000
# 9998  0.401942         -1        1.000000
# 9999  0.048937         -1        1.000000
#
# [10000 rows x 8 columns]

# %%
df = df[["argument", "topic", "stance_WA", "WA"]]
translations = {
    -1: "a",
    1: "s"
}
#df.loc[df["stance_WA"] == 1].stance_WA = "s"
#df.loc[df["stance_WA"] == -1].stance_WA = "a"
df.columns
df['relationship'] = df.apply(lambda row: translations[row["stance_WA"]], axis=1)
df.loc[df["WA"] < threshold].stance_WA = "n"
df.loc[df["relationship"] == "n"]
# Out:
# /var/folders/h4/_k7qz1tj6jv1rpp48b422qp40000gn/T/ipykernel_48095/3462212155.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df["WA"] < threshold].stance_WA = "n"
#                                                 argument  \
# 0      "marriage" isn't keeping up with the times.  a...
# 1      .a multi-party system would be too confusing a...
# 2      \ero-tolerance policy in schools should not be...
# 3      `people reach their limit when it comes to the...
# 4      100% agree, should they do that, it would be a...
# ...                                                  ...
# 30492  zoos trap animals into a meaningless life only...
# 30493  zoos treat animals badly they should be closed...
# 30494  zoos unfairly imprison animals and cause them ...
# 30495  Zoos work as educational centers and are not t...
# 30496         zoos work to help breed endangered species
#
#                                                    topic  stance_WA        WA  \
# 0                             We should abandon marriage          1  0.846165
# 1                   We should adopt a multi-party system         -1  0.891271
# 2      We should adopt a zero-tolerance policy in sch...         -1  0.721192
# 3          Assisted suicide should be a criminal offence         -1  0.730395
# 4                          We should abolish safe spaces          1  0.236686
# ...                                                  ...        ...       ...
# 30492                             We should abolish zoos          1  0.956296
# 30493                             We should abolish zoos          1  0.757601
# 30494                             We should abolish zoos          1  0.980966
# 30495                             We should abolish zoos         -1  0.841556
# 30496                             We should abolish zoos         -1  0.841521
#
#       relationship
# 0                s
# 1                a
# 2                a
# 3                a
# 4                s
# ...            ...
# 30492            s
# 30493            s
# 30494            s
# 30495            a
# 30496            a
#
# [30497 rows x 5 columns]

# %%
df = df[["argument", "topic", "relationship"]]
df.columns = ["argument1", "argument2", "relationship"]
df

# %%
df = df.to_csv("IBM30K.csv")
