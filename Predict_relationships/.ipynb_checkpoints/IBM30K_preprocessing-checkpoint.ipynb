# %%
import pandas as pd
df = pd.read_csv('../../datasets/IBM_Debater_(R)_arg_quality_rank_30k/arg_quality_rank_30k.csv')
df_ACM = pd.read_csv('../../datasets/ACM.csv')
df["relationship"] = ""
#th_element = df.sort_values(by=['WA']).iloc[10000]
#threshold = th_element.WA
#print(threshold)

#df.loc[df["stance_WA"] == 1].count()
#df.loc[df["stance_WA"] == -1].count()

# %%
df = df[["argument", "topic", "stance_WA", "WA"]]
translations = {
    -1: "a",
    1: "s"
}
df.loc[df["stance_WA"] == 1, "relationship"] = "s"
df.loc[df["stance_WA"] == -1, "relationship"] = "a"
#df.loc[df["WA"] < threshold, "relationship"] = "n"
#df.loc[df["relationship"] == "n"]

# %%
df_ACM_n = df_ACM.loc[df_ACM["relationship"] == "n"]
df_ACM_n = df_ACM_n[["argument1", "argument2", "relationship"]]
# Out:
#       Unnamed: 0                                          argument1  \
# 0              0  Labour should be running scared of UKIP, now t...
# 1              1  If UKIP don't like being smeared, then they ne...
# 2              2  I don't believe Farage is a racist and I don't...
# 3              3  Even a UKIP European candidate, Janice Atkinso...
# 5              5  The hate campaign against Eastern Europeans th...
# ...          ...                                                ...
# 2264        2264  The UKIP party is a populist party at the righ...
# 2266        2266  UKIP's proposals on membership in the EU and m...
# 2268        2268  UKIP are in with the City as much as the other...
# 2269        2269  The UKIP party is a populist party at the righ...
# 2272        2272  The hate campaign against Eastern Europeans th...
#
#                                               argument2 relationship
# 0     It shows how weak David Cameron has become and...            n
# 1     The by-election was called after former Lib De...            n
# 2               No other elections took place in Wales.            n
# 3     While Mr Farage did not put a figure on the es...            n
# 5     The UKIP leader also shared his view that the ...            n
# ...                                                 ...          ...
# 2264  Therefore, if he can argue that he has taken t...            n
# 2266  Grant Shapps said the revised seats would be r...            n
# 2268  The Conservatives have argued the surge in sup...            n
# 2269  Mr Cameron has promised an in/out referendum a...            n
# 2272  Stuart Wheeler has denied being sexist by sayi...            n
#
# [1394 rows x 4 columns]

# %%
df = df[["argument", "topic", "relationship"]]
df.columns = ["argument1", "argument2", "relationship"]
df
# Out:
#                                                argument1  \
# 0      "marriage" isn't keeping up with the times.  a...
# 1      .a multi-party system would be too confusing a...
# 2      \ero-tolerance policy in schools should not be...
# 3      `people reach their limit when it comes to the...
# 4      100% agree, should they do that, it would be a...
# ...                                                  ...
# 30492  zoos trap animals into a meaningless life only...
# 30493  zoos treat animals badly they should be closed...
# 30494  zoos unfairly imprison animals and cause them ...
# 30495  Zoos work as educational centers and are not t...
# 30496         zoos work to help breed endangered species
#
#                                                argument2 relationship
# 0                             We should abandon marriage            s
# 1                   We should adopt a multi-party system            a
# 2      We should adopt a zero-tolerance policy in sch...            n
# 3          Assisted suicide should be a criminal offence            n
# 4                          We should abolish safe spaces            n
# ...                                                  ...          ...
# 30492                             We should abolish zoos            s
# 30493                             We should abolish zoos            s
# 30494                             We should abolish zoos            s
# 30495                             We should abolish zoos            a
# 30496                             We should abolish zoos            a
#
# [30497 rows x 3 columns]

# %%
df = df.to_csv("IBM30K_with_n.csv")
